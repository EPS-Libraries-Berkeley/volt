# %% [markdown]
# # Searching for articles with APIs

# %%
import urllib
import arxiv
import requests
import json
import csv

# %%
#url = 'http://export.arxiv.org/api/query?search_query=all:electron&start=0&max_results=10'
#data = urllib.request.urlopen(url).read()

# %%
#print(data)

# %%
#url = 'http://export.arxiv.org/api/query?search_query=au:del_maestro+AND+ti:%22quantum+criticality%22'
#data2 = urllib.request.urlopen(url).read()

# %%
#data2

# %%
arxiv.query(query="quantum dots", max_results=100)
# Out:
# [{'id': 'http://arxiv.org/abs/1812.08931v1',
#   'guidislink': True,
#   'updated': '2018-12-21T03:50:15Z',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=12, tm_mday=21, tm_hour=3, tm_min=50, tm_sec=15, tm_wday=4, tm_yday=355, tm_isdst=0),
#   'published': '2018-12-21T03:50:15Z',
#   'published_parsed': time.struct_time(tm_year=2018, tm_mon=12, tm_mday=21, tm_hour=3, tm_min=50, tm_sec=15, tm_wday=4, tm_yday=355, tm_isdst=0),
#   'title': 'Band Modulation for Silicene and Graphene Quantum Dots: A\n  First-Principles Calculation',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://export.arxiv.org/api/query?search_query=quantum+dots&id_list=&start=0&max_results=100&sortBy=relevance&sortOrder=descending',
#    'value': 'Band Modulation for Silicene and Graphene Quantum Dots: A\n  First-Principles Calculation'},
# ...

# %%
result = arxiv.query(
  query="quantum dots",
  max_chunk_results=10,
  max_results=100,
  iterative=True
)

for paper in result():
   print(paper)
# Out:
# {'id': 'http://arxiv.org/abs/1812.08931v1', 'guidislink': True, 'updated': '2018-12-21T03:50:15Z', 'updated_parsed': time.struct_time(tm_year=2018, tm_mon=12, tm_mday=21, tm_hour=3, tm_min=50, tm_sec=15, tm_wday=4, tm_yday=355, tm_isdst=0), 'published': '2018-12-21T03:50:15Z', 'published_parsed': time.struct_time(tm_year=2018, tm_mon=12, tm_mday=21, tm_hour=3, tm_min=50, tm_sec=15, tm_wday=4, tm_yday=355, tm_isdst=0), 'title': 'Band Modulation for Silicene and Graphene Quantum Dots: A\n  First-Principles Calculation', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum+dots&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Band Modulation for Silicene and Graphene Quantum Dots: A\n  First-Principles Calculation'}, 'summary': 'The band modulation of the silicene and graphene quantum dots is investigated\nby a first-principles method. This study includes the ordinary silicene and\ngraph
# ...

# %%
#create dataframe

# %%
#see who is publishing on topic, author groupby/sort

# %%
#search by affiliation - what is affiliation code?

# %%
#identify trending topic

# %%
#identify and download papers
